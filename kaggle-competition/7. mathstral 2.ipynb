# %%
import os
os.environ['HF_HOME'] = '/run/cache/'

# %% [markdown]
# # Preparing model

# %%
# !pip install --upgrade deepspeed
# !pip install --upgrade pydantic
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: deepspeed in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (0.10.0)
# Collecting deepspeed
#   Downloading deepspeed-0.14.4.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.8 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: hjson in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (3.1.0)
# Requirement already satisfied: ninja in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (1.11.1)
# Requirement already satisfied: numpy in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (1.24.4)
# Collecting nvidia-ml-py (from deepspeed)
#   Obtaining dependency information for nvidia-ml-py from https://files.pythonhosted.org/packages/50/13/fcc6b604dea9782d69e675b1481af16e9a02c44d1d43819af209b0a1e6bb/nvidia_ml_py-12.555.43-py3-none-any.whl.metadata
#   Downloading nvidia_ml_py-12.555.43-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (23.1)
# Requirement already satisfied: psutil in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (9.0.0)
# Requirement already satisfied: pydantic in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (2.8.2)
# Requirement already satisfied: torch in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (2.4.0)
# Requirement already satisfied: tqdm in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from deepspeed) (4.65.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic->deepspeed) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic->deepspeed) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic->deepspeed) (4.12.2)
# Requirement already satisfied: filelock in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (3.12.2)
# Requirement already satisfied: sympy in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (1.12)
# Requirement already satisfied: networkx in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (3.1)
# Requirement already satisfied: jinja2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (3.1.2)
# Requirement already satisfied: fsspec in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from torch->deepspeed) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->deepspeed) (12.6.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from jinja2->torch->deepspeed) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from sympy->torch->deepspeed) (1.3.0)
# Downloading nvidia_ml_py-12.555.43-py3-none-any.whl (39 kB)
# Building wheels for collected packages: deepspeed
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.14.4-py3-none-any.whl size=1445516 sha256=9262491ddc464ea52b31080c05c99df36b82377c55912e569a8a8a791f2fe41e
#   Stored in directory: /home/jovyan/.cache/pip/wheels/68/2c/db/7164d811bdcb8a22883431b03eefc1478cf3bfafd45022cf1a
# Successfully built deepspeed
# Installing collected packages: nvidia-ml-py, deepspeed
#   Attempting uninstall: deepspeed
#     Found existing installation: deepspeed 0.10.0
#     Uninstalling deepspeed-0.10.0:
#       Successfully uninstalled deepspeed-0.10.0
# Successfully installed deepspeed-0.14.4 nvidia-ml-py-12.555.43
# Requirement already satisfied: pydantic in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (2.8.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: transformers in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (4.44.0)
# Requirement already satisfied: filelock in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (0.24.5)
# Requirement already satisfied: numpy>=1.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->transformers) (2023.7.22)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
from huggingface_hub import login, snapshot_download
from pathlib import Path

# %%
mistral_models_path = Path.home().joinpath('mistral_models', 'Mathstral-7b-v0.1')
mistral_models_path.mkdir(parents=True, exist_ok=True)

# %%
login(token=os.environ['HF_TOKEN'])
snapshot_download(repo_id="mistralai/Mathstral-7b-v0.1", allow_patterns=["params.json", "consolidated.safetensors", "tokenizer.model.v3"], local_dir=mistral_models_path)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /run/cache/token
# Login successful
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# '/home/jovyan/mistral_models/Mathstral-7b-v0.1'

# %% [markdown]
# # Проверяем модель

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

checkpoint = "mistralai/Mathstral-7b-v0.1"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint, device_map="auto", torch_dtype=torch.bfloat16)
# Out:
# [2024-08-13 01:51:53,435] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /opt/saturncloud/envs/saturn/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  NVIDIA Inference is only supported on Ampere and newer architectures
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.4
#  [WARNING]  using untested triton version (3.0.0), only 1.0.0 is known to be compatible
# /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
prompt = [{"role": "user", "content": "What are the roots of unity?"}]
tokenized_prompt = tokenizer.apply_chat_template(prompt, add_generation_prompt=True, return_dict=True, return_tensors="pt").to(model.device)

out = model.generate(**tokenized_prompt, max_new_tokens=512)
tokenizer.decode(out[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# '<s>[INST] What are the roots of unity?[/INST] The roots of unity are the complex numbers that satisfy the equation $z^n = 1$, where $n$ is a positive integer. These roots are evenly spaced around the unit circle in the complex plane, and they have a variety of interesting properties and applications in mathematics and science.</s>'

# %% [markdown]
# # Оформляем в функцию

# %%
def solve_math_problem(tokenizer, model, problem):
    prompt = [
        {"role": "system", "content": "You are a helpful math assistant. Solve the given problem step by step, showing your reasoning."},
        {"role": "user", "content": f"Solve this math problem: {problem}"}
    ]

    tokenized_prompt = tokenizer.apply_chat_template(prompt, add_generation_prompt=True, return_dict=True, return_tensors="pt").to(model.device)

    output = model.generate(**tokenized_prompt, max_new_tokens=512)
    full_response = tokenizer.decode(output[0], skip_special_tokens=True)

    # Удаление промпта и исходного вопроса из ответа
    response_parts = full_response.split("Solve this math problem:")
    if len(response_parts) > 1:
        clean_response = response_parts[1].strip()
    else:
        clean_response = "Unable to extract the solution from the model's response."

    return clean_response

# %%
problem = "Find the value of the expression $\dfrac{2\strut^{-5} \cdot 2\strut^{9} }{2\strut^{-4} } $."

# %%
result = solve_math_problem(tokenizer, model, problem)
print("Solution:")
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Solution:
# Find the value of the expression $\dfrac{2\strut^{-5} \cdot 2\strut^{9} }{2\strut^{-4} } $. Sure, let's solve this step by step:
#
# 1. First, let's simplify the numerator of the fraction. The expression $2^{-5} \cdot 2^{9}$ can be simplified using the rule of exponents that states $a^m \cdot a^n = a^{m+n}$. So, $2^{-5} \cdot 2^{9} = 2^{-5+9} = 2^{4}$.
#
# 2. Now, let's simplify the denominator of the fraction. The expression $2^{-4}$ is already simplified.
#
# 3. So, the original expression $\dfrac{2\strut^{-5} \cdot 2\strut^{9} }{2\strut^{-4} }$ simplifies to $\dfrac{2^{4}}{2^{-4}}$.
#
# 4. To simplify this further, we can use the rule of exponents that states $\dfrac{a^m}{a^n} = a^{m-n}$. So, $\dfrac{2^{4}}{2^{-4}} = 2^{4-(-4)} = 2^{4+4} = 2^{8}$.
#
# 5. Finally, we calculate $2^{8}$ to get the final answer.
#
# \boxed{256}

# %% [markdown]
# # Решения из трейна

# %%
from tqdm import tqdm
import pandas as pd

# %%
train = pd.read_csv('https://github.com/DataTalksClub/llm-zoomcamp/raw/main/cohorts/2024/competition/data/train.csv')

# %%
train10 = train.iloc[0:10,]

# %%
train10
# Out:
#    problem_id                                       problem_text        answer
# 0        2374  Find the value of the expression $\dfrac{17}{5...           1.6
# 1        4723  In a company of 30 people, 25 use the social n...            24
# 2        7135  The number of road traffic accidents (RTAs) in...            32
# 3        5814  Find the value of the expression $\dfrac{2\str...           256
# 4        9237  A traveler from Moscow wants to visit four cit...            53
# 5       10703  At the end of the term, Vovochka wrote down al...             3
# 6        9621  Find a four-digit number that is 11 times smal...  27000; 64000
# 7        4318  Find the value of the expression $\dfrac{\sqrt...             2
# 8        7549  The harmonic mean of three numbers $a$, $b$, a...           0.1
# 9        4405  Find \(\tan x\) if \(\sin x = \dfrac{6}{\sqrt{...           1.2

# %%
def process_dataframe(df):
    # Создаем новую колонку для ответов модели
    df['model_answer'] = ''

    # Используем tqdm для создания прогресс-бара
    for index in tqdm(df.index, desc="Processing questions"):
        question = df.loc[index, 'problem_text']
        answer = solve_math_problem(tokenizer, model, question)
        df.loc[index, 'model_answer'] = answer

    return df

# %%
process_dataframe(train10)
# Out:
# /tmp/ipykernel_2614/1083306690.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['model_answer'] = ''
# Processing questions:   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  10%|█         | 1/10 [00:19<02:51, 19.11s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  20%|██        | 2/10 [00:54<03:49, 28.74s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  30%|███       | 3/10 [01:11<02:44, 23.44s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  40%|████      | 4/10 [01:30<02:10, 21.74s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  50%|█████     | 5/10 [02:07<02:14, 26.95s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  60%|██████    | 6/10 [02:41<01:58, 29.67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  70%|███████   | 7/10 [03:15<01:33, 31.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  80%|████████  | 8/10 [03:25<00:48, 24.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  90%|█████████ | 9/10 [03:48<00:23, 23.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions: 100%|██████████| 10/10 [04:10<00:00, 25.08s/it]
#    problem_id                                       problem_text  \
# 0        2374  Find the value of the expression $\dfrac{17}{5...
# 1        4723  In a company of 30 people, 25 use the social n...
# 2        7135  The number of road traffic accidents (RTAs) in...
# 3        5814  Find the value of the expression $\dfrac{2\str...
# 4        9237  A traveler from Moscow wants to visit four cit...
# 5       10703  At the end of the term, Vovochka wrote down al...
# 6        9621  Find a four-digit number that is 11 times smal...
# 7        4318  Find the value of the expression $\dfrac{\sqrt...
# 8        7549  The harmonic mean of three numbers $a$, $b$, a...
# 9        4405  Find \(\tan x\) if \(\sin x = \dfrac{6}{\sqrt{...
#
#          answer                                       model_answer
# 0           1.6  Find the value of the expression $\dfrac{17}{5...
# 1            24  In a company of 30 people, 25 use the social n...
# 2            32  The number of road traffic accidents (RTAs) in...
# 3           256  Find the value of the expression $\dfrac{2\str...
# 4            53  A traveler from Moscow wants to visit four cit...
# 5             3  At the end of the term, Vovochka wrote down al...
# 6  27000; 64000  Find a four-digit number that is 11 times smal...
# 7             2  Find the value of the expression $\dfrac{\sqrt...
# 8           0.1  The harmonic mean of three numbers $a$, $b$, a...
# 9           1.2  Find \(\tan x\) if \(\sin x = \dfrac{6}{\sqrt{...

# %%
train10

# %% [markdown]
# # Достаем ответ с помощью HAIKU

# %%
# !pip install anthropic
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting anthropic
#   Obtaining dependency information for anthropic from https://files.pythonhosted.org/packages/8a/0c/2ba7c72b2f7176a5583f76b72df737cd7b2d842301afe63a63abcfb2f6f8/anthropic-0.33.1-py3-none-any.whl.metadata
#   Downloading anthropic-0.33.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anthropic) (3.7.1)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anthropic) (0.24.1)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Obtaining dependency information for jiter<1,>=0.4.0 from https://files.pythonhosted.org/packages/c1/62/16ca89739acd12308a7d1f07af81edac2fecd2f813f65fc6d12c53afa65a/jiter-0.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading jiter-0.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anthropic) (2.8.2)
# Requirement already satisfied: sniffio in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anthropic) (1.3.0)
# Requirement already satisfied: tokenizers>=0.13.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anthropic) (0.19.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anthropic) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (3.4)
# Requirement already satisfied: exceptiongroup in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anyio<5,>=3.5.0->anthropic) (1.1.2)
# Requirement already satisfied: certifi in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from httpx<1,>=0.23.0->anthropic) (2023.7.22)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from httpx<1,>=0.23.0->anthropic) (0.17.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.20.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from tokenizers>=0.13.0->anthropic) (0.24.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->anthropic) (0.14.0)
# Requirement already satisfied: filelock in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (6.0.1)
# Requirement already satisfied: requests in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.0.4)
# Downloading anthropic-0.33.1-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.9/866.9 kB 17.5 MB/s eta 0:00:00a 0:00:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 49.9 MB/s eta 0:00:00
# Installing collected packages: jiter, distro, anthropic
# Successfully installed anthropic-0.33.1 distro-1.9.0 jiter-0.5.0

# %%
import anthropic
import re

# %%
def extract_math_answer(text):
    client = anthropic.Anthropic()
    system = """
    You are an AI assistant specialized in extracting numerical answers from mathematical solutions.
    Your task is to analyze the given mathematical solution and return only the final numerical answer.
    If the answer is in a LaTeX \boxed{} environment, extract the content inside the box.
    Do not include any explanations, just return the number. Only number, not text like: The final answer is ...
    Use only number and symbols . (dot), decimal answer (no fractions)
    """

    user_text = f"Extract the final numerical answer from this mathematical solution:\n\n{text}"

    message = client.messages.create(
        model="claude-3-haiku-20240307",
        max_tokens=100,
        temperature=0,
        system=system,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": user_text
                    }
                ]
            }
        ]
    )

    answer = message.content[0].text.strip()
    
    # If the answer is still in LaTeX format, extract the number
    latex_match = re.search(r'\\boxed{(\d+)}', answer)
    if latex_match:
        answer = latex_match.group(1)

    return answer

# %%
def process_dataframe_2(df):
    # Создаем новую колонку для ответов модели
    df['parsed_answer'] = ''

    # Используем tqdm для создания прогресс-бара
    for index in tqdm(df.index, desc="Processing questions"):
        model_answer = df.loc[index, 'model_answer']
        df.loc[index, 'parsed_answer'] = extract_math_answer(model_answer)

    return df

# %%
process_dataframe_2(train10)
# Out:
# /tmp/ipykernel_2614/57174912.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['parsed_answer'] = ''
# Processing questions: 100%|██████████| 10/10 [00:06<00:00,  1.64it/s]
#    problem_id                                       problem_text  \
# 0        2374  Find the value of the expression $\dfrac{17}{5...
# 1        4723  In a company of 30 people, 25 use the social n...
# 2        7135  The number of road traffic accidents (RTAs) in...
# 3        5814  Find the value of the expression $\dfrac{2\str...
# 4        9237  A traveler from Moscow wants to visit four cit...
# 5       10703  At the end of the term, Vovochka wrote down al...
# 6        9621  Find a four-digit number that is 11 times smal...
# 7        4318  Find the value of the expression $\dfrac{\sqrt...
# 8        7549  The harmonic mean of three numbers $a$, $b$, a...
# 9        4405  Find \(\tan x\) if \(\sin x = \dfrac{6}{\sqrt{...
#
#          answer                                       model_answer  \
# 0           1.6  Find the value of the expression $\dfrac{17}{5...
# 1            24  In a company of 30 people, 25 use the social n...
# 2            32  The number of road traffic accidents (RTAs) in...
# 3           256  Find the value of the expression $\dfrac{2\str...
# 4            53  A traveler from Moscow wants to visit four cit...
# 5             3  At the end of the term, Vovochka wrote down al...
# 6  27000; 64000  Find a four-digit number that is 11 times smal...
# 7             2  Find the value of the expression $\dfrac{\sqrt...
# 8           0.1  The harmonic mean of three numbers $a$, $b$, a...
# 9           1.2  Find \(\tan x\) if \(\sin x = \dfrac{6}{\sqrt{...
#
#   parsed_answer
# 0           1.6
# 1            24
# 2            32
# 3           256
# 4          8950
# 5             4
# 6            33
# 7             2
# 8           0.1
# 9           1.2

# %% [markdown]
# # Решаем TEST задачи

# %%
test = pd.read_csv('https://github.com/DataTalksClub/llm-zoomcamp/raw/main/cohorts/2024/competition/data/test.csv')

# %%
process_dataframe(test)
process_dataframe_2(test)
# Out:
# Processing questions:   0%|          | 0/100 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   1%|          | 1/100 [00:06<10:12,  6.19s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   2%|▏         | 2/100 [00:22<19:28, 11.92s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   3%|▎         | 3/100 [00:31<17:11, 10.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   4%|▍         | 4/100 [00:51<23:05, 14.43s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   5%|▌         | 5/100 [01:02<21:02, 13.29s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   6%|▌         | 6/100 [01:16<20:59, 13.40s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   7%|▋         | 7/100 [01:26<19:06, 12.33s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   8%|▊         | 8/100 [01:50<24:39, 16.09s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:   9%|▉         | 9/100 [02:16<29:12, 19.26s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  10%|█         | 10/100 [02:47<34:16, 22.85s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  11%|█         | 11/100 [03:21<39:01, 26.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  12%|█▏        | 12/100 [03:32<31:35, 21.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  13%|█▎        | 13/100 [03:46<27:50, 19.20s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  14%|█▍        | 14/100 [04:03<26:45, 18.66s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  15%|█▌        | 15/100 [04:22<26:28, 18.69s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  16%|█▌        | 16/100 [04:37<24:44, 17.67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  17%|█▋        | 17/100 [04:59<26:14, 18.97s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  18%|█▊        | 18/100 [05:17<25:17, 18.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  19%|█▉        | 19/100 [05:32<23:50, 17.67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  20%|██        | 20/100 [06:07<30:22, 22.78s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  21%|██        | 21/100 [06:31<30:31, 23.18s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  22%|██▏       | 22/100 [06:40<24:24, 18.78s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  23%|██▎       | 23/100 [06:52<21:36, 16.84s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  24%|██▍       | 24/100 [07:27<28:06, 22.19s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  25%|██▌       | 25/100 [07:39<23:54, 19.12s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  26%|██▌       | 26/100 [07:52<21:36, 17.52s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  27%|██▋       | 27/100 [08:29<28:22, 23.32s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  28%|██▊       | 28/100 [08:45<25:11, 20.99s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  29%|██▉       | 29/100 [09:02<23:29, 19.85s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  30%|███       | 30/100 [09:12<19:36, 16.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  31%|███       | 31/100 [09:32<20:25, 17.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  32%|███▏      | 32/100 [09:53<21:12, 18.72s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  33%|███▎      | 33/100 [10:12<21:11, 18.98s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  34%|███▍      | 34/100 [10:28<19:45, 17.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  35%|███▌      | 35/100 [10:52<21:23, 19.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  36%|███▌      | 36/100 [11:23<24:51, 23.30s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  37%|███▋      | 37/100 [11:33<20:15, 19.29s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  38%|███▊      | 38/100 [11:55<20:38, 19.97s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  39%|███▉      | 39/100 [12:14<20:00, 19.69s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  40%|████      | 40/100 [12:25<17:14, 17.24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  41%|████      | 41/100 [12:50<19:10, 19.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  42%|████▏     | 42/100 [13:03<16:52, 17.45s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  43%|████▎     | 43/100 [13:37<21:17, 22.41s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  44%|████▍     | 44/100 [13:49<17:55, 19.21s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  45%|████▌     | 45/100 [14:04<16:28, 17.97s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  46%|████▌     | 46/100 [14:21<16:02, 17.82s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  47%|████▋     | 47/100 [14:58<20:43, 23.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  48%|████▊     | 48/100 [15:29<22:22, 25.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  49%|████▉     | 49/100 [16:03<24:01, 28.26s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  50%|█████     | 50/100 [16:17<19:53, 23.87s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  51%|█████     | 51/100 [16:24<15:22, 18.83s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  52%|█████▏    | 52/100 [17:01<19:29, 24.37s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  53%|█████▎    | 53/100 [17:36<21:30, 27.45s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  54%|█████▍    | 54/100 [18:10<22:37, 29.50s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  55%|█████▌    | 55/100 [18:30<19:55, 26.57s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  56%|█████▌    | 56/100 [18:40<15:59, 21.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  57%|█████▋    | 57/100 [19:14<18:15, 25.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  58%|█████▊    | 58/100 [19:29<15:28, 22.12s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  59%|█████▉    | 59/100 [19:41<13:05, 19.15s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  60%|██████    | 60/100 [20:17<16:12, 24.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  61%|██████    | 61/100 [20:36<14:45, 22.72s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  62%|██████▏   | 62/100 [20:56<13:50, 21.85s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  63%|██████▎   | 63/100 [21:16<13:09, 21.35s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  64%|██████▍   | 64/100 [21:50<15:05, 25.16s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  65%|██████▌   | 65/100 [22:03<12:28, 21.39s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  66%|██████▌   | 66/100 [22:39<14:35, 25.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  67%|██████▋   | 67/100 [23:03<13:52, 25.22s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  68%|██████▊   | 68/100 [23:37<14:51, 27.87s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  69%|██████▉   | 69/100 [24:11<15:22, 29.75s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  70%|███████   | 70/100 [24:47<15:50, 31.68s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  71%|███████   | 71/100 [25:14<14:33, 30.13s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  72%|███████▏  | 72/100 [25:25<11:25, 24.48s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  73%|███████▎  | 73/100 [25:39<09:35, 21.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  74%|███████▍  | 74/100 [26:05<09:49, 22.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  75%|███████▌  | 75/100 [26:21<08:34, 20.59s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  76%|███████▌  | 76/100 [26:48<09:01, 22.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  77%|███████▋  | 77/100 [27:22<10:03, 26.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  78%|███████▊  | 78/100 [28:00<10:53, 29.71s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  79%|███████▉  | 79/100 [28:14<08:44, 24.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  80%|████████  | 80/100 [28:27<07:07, 21.38s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  81%|████████  | 81/100 [29:03<08:09, 25.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  82%|████████▏ | 82/100 [29:37<08:26, 28.13s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  83%|████████▎ | 83/100 [30:03<07:47, 27.49s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  84%|████████▍ | 84/100 [30:22<06:39, 24.99s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  85%|████████▌ | 85/100 [30:44<06:03, 24.24s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  86%|████████▌ | 86/100 [30:59<04:57, 21.23s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  87%|████████▋ | 87/100 [31:19<04:33, 21.06s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  88%|████████▊ | 88/100 [31:34<03:49, 19.10s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  89%|████████▉ | 89/100 [32:08<04:19, 23.56s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  90%|█████████ | 90/100 [32:15<03:05, 18.54s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  91%|█████████ | 91/100 [32:50<03:32, 23.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  92%|█████████▏| 92/100 [33:07<02:51, 21.47s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  93%|█████████▎| 93/100 [33:17<02:05, 18.00s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  94%|█████████▍| 94/100 [33:35<01:48, 18.02s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  95%|█████████▌| 95/100 [33:49<01:23, 16.79s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  96%|█████████▌| 96/100 [34:25<01:30, 22.60s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  97%|█████████▋| 97/100 [34:51<01:11, 23.78s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  98%|█████████▊| 98/100 [35:27<00:54, 27.45s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions:  99%|█████████▉| 99/100 [35:44<00:24, 24.36s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processing questions: 100%|██████████| 100/100 [36:06<00:00, 21.67s/it]
# Processing questions: 100%|██████████| 100/100 [01:05<00:00,  1.53it/s]
#     problem_id                                       problem_text  \
# 0        11919  Find the value of the expression \(4.8 \cdot 2...
# 1         8513  The plane's navigation system informs the pass...
# 2         7887  The volume of a rectangular parallelepiped is ...
# 3         5272  Find the root of the equation: $\left(\dfrac{1...
# 4         8295  At the school, there are two-person camping te...
# ..         ...                                                ...
# 95        3519  A tourist is selecting tours. Information abou...
# 96        7934  The area of a triangle can be calculated using...
# 97        9390  A construction contractor plans to buy 20 tons...
# 98        7137  The number of road traffic accidents (RTAs) in...
# 99        5914  Find the value of the expression $\dfrac{2.4\c...
#
#                                          model_answer  parsed_answer
# 0   Find the value of the expression \(4.8 \cdot 2...             12
# 1   The plane's navigation system informs the pass...          11245
# 2   The volume of a rectangular parallelepiped is ...              4
# 3   Find the root of the equation: $\left(\dfrac{1...              6
# 4   At the school, there are two-person camping te...             13
# ..                                                ...            ...
# 95  A tourist is selecting tours. Information abou...            650
# 96  The area of a triangle can be calculated using...             12
# 97  A construction contractor plans to buy 20 tons...  256000 rubles
# 98  The number of road traffic accidents (RTAs) in...             22
# 99  Find the value of the expression $\dfrac{2.4\c...              3
#
# [100 rows x 4 columns]

# %%
test
# Out:
#                                                  problem_text  \
# problem_id
# 11919       Find the value of the expression \(4.8 \cdot 2...
# 8513        The plane's navigation system informs the pass...
# 7887        The volume of a rectangular parallelepiped is ...
# 5272        Find the root of the equation: $\left(\dfrac{1...
# 8295        At the school, there are two-person camping te...
# ...                                                       ...
# 3519        A tourist is selecting tours. Information abou...
# 7934        The area of a triangle can be calculated using...
# 9390        A construction contractor plans to buy 20 tons...
# 7137        The number of road traffic accidents (RTAs) in...
# 5914        Find the value of the expression $\dfrac{2.4\c...
#
#                                                  model_answer  parsed_answer
# problem_id
# 11919       Find the value of the expression \(4.8 \cdot 2...             12
# 8513        The plane's navigation system informs the pass...          11245
# 7887        The volume of a rectangular parallelepiped is ...              4
# 5272        Find the root of the equation: $\left(\dfrac{1...              6
# 8295        At the school, there are two-person camping te...             13
# ...                                                       ...            ...
# 3519        A tourist is selecting tours. Information abou...            650
# 7934        The area of a triangle can be calculated using...             12
# 9390        A construction contractor plans to buy 20 tons...  256000 rubles
# 7137        The number of road traffic accidents (RTAs) in...             22
# 5914        Find the value of the expression $\dfrac{2.4\c...              3
#
# [100 rows x 3 columns]

# %% [markdown]
# # Make sumbit

# %%
def make_submit(answers: pd.Series, filename="data/my_submit.csv"):
    answer_df = answers.reset_index()
    answer_df.columns = ["problem_id", "answer"]
    answer_df.to_csv(filename, index=False)

# %%
test.set_index('problem_id', inplace=True)

# %%
make_submit(test.parsed_answer, filename="my_submit_7_mathstral.csv")

# %%
def clean_numeric_column(df, column_name):
    def clean_value(value):
        if pd.isna(value):
            return value
        
        # Convert to string if not already
        value = str(value)
        
        # Remove all non-digit characters except for comma and dot
        cleaned = re.sub(r'[^\d,.]', '', value)
        
        # Replace comma with dot for decimal separator
        cleaned = cleaned.replace(',', '.')
        
        # Try to convert to float
        try:
            return float(cleaned)
        except ValueError:
            return np.nan  # Return NaN if conversion fails

    # Apply the cleaning function to the specified column
    df[column_name] = df[column_name].apply(clean_value)
    
    return df

# %%
import numpy as np

# %%
clean_numeric_column(test, "parsed_answer")
test
# Out:
#                                                  problem_text  \
# problem_id
# 11919       Find the value of the expression \(4.8 \cdot 2...
# 8513        The plane's navigation system informs the pass...
# 7887        The volume of a rectangular parallelepiped is ...
# 5272        Find the root of the equation: $\left(\dfrac{1...
# 8295        At the school, there are two-person camping te...
# ...                                                       ...
# 3519        A tourist is selecting tours. Information abou...
# 7934        The area of a triangle can be calculated using...
# 9390        A construction contractor plans to buy 20 tons...
# 7137        The number of road traffic accidents (RTAs) in...
# 5914        Find the value of the expression $\dfrac{2.4\c...
#
#                                                  model_answer  parsed_answer
# problem_id
# 11919       Find the value of the expression \(4.8 \cdot 2...           12.0
# 8513        The plane's navigation system informs the pass...        11245.0
# 7887        The volume of a rectangular parallelepiped is ...            4.0
# 5272        Find the root of the equation: $\left(\dfrac{1...            6.0
# 8295        At the school, there are two-person camping te...           13.0
# ...                                                       ...            ...
# 3519        A tourist is selecting tours. Information abou...          650.0
# 7934        The area of a triangle can be calculated using...           12.0
# 9390        A construction contractor plans to buy 20 tons...       256000.0
# 7137        The number of road traffic accidents (RTAs) in...           22.0
# 5914        Find the value of the expression $\dfrac{2.4\c...            3.0
#
# [100 rows x 3 columns]

# %%
test.parsed_answer.fillna(0, inplace=True)

# %%
make_submit(test.parsed_answer, filename="my_submit_7_1_mathstral.csv")
